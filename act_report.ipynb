# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### REPORT

# %% [markdown]
# - After the data wrangling process, I came up with some insights based on my analysis. These were:
#    > Do the retweets increase over time?
#
#    > Does a dog's rating affect the retweet count/favourite count?
#
#    > Are the most retweeted tweets the ones with the highest favourite count?
#
# - My insights were mostly questions that I had from my analysis and I derived my answers from visualizations including histograms, line plots and scatter plots from libraries such as matplolib.
# - I used histograms to get an approximation of the data representation from the retweet count and favorite columns.
# - I used a stacked histogram to compare the number of retweets and favorite count.
# - The scatter plots I plotted were very useful in finding the relationship between various variables. For example, if the dogs' ratings affected the number of retweets a post got.
# - The line plot that plotted the number of retweets with time by using the 'Timestamp' and 'retweet_count' columns, really showed the relationship very clearly.
# - From these visualizations, I was able to come to a couple of conclusions including:
#    > Based on the scatter plot, it showed there was a negative relationship, almost no relationship at all between Retweets count and the dogs' rating. The ratings the dogs were given did not really affect the number of times a tweet/post was retweeted. This signified that people who retweeted the posts did so based on their own judgement of how the dogs appealed to their eyes.
#
#    > The increase in the number of retweets increased over time although the change was not as constant as that of favorite count. This could maybe signify that the WeRateDogs account got more followers most of who reacted to the tweets by liking and not retweeting.
#
#    > The stacked histogram showed that the number of favorite counts was higher than that of reweet count meaning that most of the tweets received likes from people and not retweets even though there's also a high number of retweets.
#
# - One of the visualization I used in my analysis was a scatter plot as shown by the code below:
#    > df_clean_twitter.plot(kind='scatter', x='Tweet_id', y='favorite_count').
#
#    > The result of the code was ![image.png](attachment:image.png)
